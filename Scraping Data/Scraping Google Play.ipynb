# %% [markdown]
# ### Nama : Atina Nora Haya
# ### NIM    : 2211110043
# ### Kelas : SD03B

# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.4-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.4

# %%
from google_play_scraper import Sort, reviews, app
import pandas as pd
import numpy as np

# %%
result, continuation_token = reviews(
    'com.instagram.android',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=1000,
    filter_score_with=None
)

# %%
data = pd.DataFrame(np.array(result), columns=['review'])
data = data.join(pd.DataFrame(data.pop('review').tolist()))

# %%
data
# Out:
#                                  reviewId               userName  \
# 0    87a9cda5-5a59-40a9-922f-e2cd00091f93      Damar Vikryansyah
# 1    4a0adde7-1266-424a-bf08-f3f825ea4f1e          Nazka Vayrena
# 2    19e76c70-ddc3-45e7-ad6e-0867efa66b08   farida haifatuzzahra
# 3    337c5e48-efbf-4603-b883-00356f4dbf31         Yudha Adistira
# 4    28920988-6d41-4b44-967b-683cb2b1c40b             Nuha 19 7K
# ..                                    ...                    ...
# 995  b337ba39-d251-4878-ac4b-55ce3a801d72        susanto hariono
# 996  b7637f73-3065-4632-bca1-bad949b79c09        Abdul Qodir BSA
# 997  dae071f4-e0c4-4b26-80a8-2b4be3062441     Luvita Puspitasari
# 998  1d0642e3-2396-4b48-88cc-50a95d6878d1     Fiddiena Lestriena
# 999  295f787f-a965-494e-ad10-37436ecd7d0f  Firgi Ardian Ramadhan
#
#                                              userImage  \
# 0    https://play-lh.googleusercontent.com/a/ACg8oc...
# 1    https://play-lh.googleusercontent.com/a-/ALV-U...
# 2    https://play-lh.googleusercontent.com/a-/ALV-U...
# 3    https://play-lh.googleusercontent.com/a-/ALV-U...
# 4    https://play-lh.googleusercontent.com/a-/ALV-U...
# ..                                                 ...
# 995  https://play-lh.googleusercontent.com/a-/ALV-U...
# 996  https://play-lh.googleusercontent.com/a/ACg8oc...
# 997  https://play-lh.googleusercontent.com/a/ACg8oc...
# 998  https://play-lh.googleusercontent.com/a/ACg8oc...
# 999  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                content  score  thumbsUpCount  \
# 0    Kurang ramah aplikasi instagram ini selalu ada...      3             79
# 1    kecewa karena musiknya jadi pada gada, ketika ...      1           5832
# 2    nggak jelas, makin di update malah jadi nggak ...      1           3698
# 3    Ada bug dimana akun utama saya tidak bisa repo...      1           1336
# 4    Tolong bug nya diperbaiki ya, ini di akun ke d...      3           1652
# ..                                                 ...    ...            ...
# 995  Aplikasi media sosial yang satu ini menghubung...      5             16
# 996  Dulu berjalan baik, semuanya normal, tpi setel...      1              3
# 997  sedih banget karena fitur baru instagram repos...      1              3
# 998  Mohon segera diperbaiki. Berbagai fitur tambah...      4              3
# 999  Kenapa setiap di tinggal terus di buka lagi ap...      5              6
#
#     reviewCreatedVersion                  at replyContent repliedAt  \
# 0         303.0.0.40.109 2023-10-04 13:10:56         None      None
# 1         300.0.0.29.110 2023-09-16 21:44:15         None      None
# 2         301.1.0.33.110 2023-09-22 22:55:59         None      None
# 3         301.1.0.33.110 2023-09-24 23:58:50         None      None
# 4         300.0.0.29.110 2023-09-17 16:17:17         None      None
# ..                   ...                 ...          ...       ...
# 995        293.0.2.28.93 2023-07-29 18:44:14         None      None
# 996       297.0.0.33.109 2023-08-28 15:40:07         None      None
# 997       297.0.0.33.109 2023-08-31 11:37:29         None      None
# 998        294.0.0.33.87 2023-08-06 13:31:08         None      None
# 999       295.0.0.32.109 2023-08-24 00:07:23         None      None
#
#          appVersion
# 0    303.0.0.40.109
# 1    300.0.0.29.110
# 2    301.1.0.33.110
# 3    301.1.0.33.110
# 4    300.0.0.29.110
# ..              ...
# 995   293.0.2.28.93
# 996  297.0.0.33.109
# 997  297.0.0.33.109
# 998   294.0.0.33.87
# 999  295.0.0.32.109
#
# [1000 rows x 11 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              1000 non-null   object
#  1   userName              1000 non-null   object
#  2   userImage             1000 non-null   object
#  3   content               1000 non-null   object
#  4   score                 1000 non-null   int64
#  5   thumbsUpCount         1000 non-null   int64
#  6   reviewCreatedVersion  1000 non-null   object
#  7   at                    1000 non-null   datetime64[ns]
#  8   replyContent          0 non-null      object
#  9   repliedAt             0 non-null      object
#  10  appVersion            1000 non-null   object
# dtypes: datetime64[ns](1), int64(2), object(8)
# memory usage: 86.1+ KB

# %%
data.isna().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of      reviewId  userName  userImage  content  score  thumbsUpCount  \
# 0       False     False      False    False  False          False
# 1       False     False      False    False  False          False
# 2       False     False      False    False  False          False
# 3       False     False      False    False  False          False
# 4       False     False      False    False  False          False
# ..        ...       ...        ...      ...    ...            ...
# 995     False     False      False    False  False          False
# 996     False     False      False    False  False          False
# 997     False     False      False    False  False          False
# 998     False     False      False    False  False          False
# 999     False     False      False    False  False          False
#
#      reviewCreatedVersion     at  replyContent  repliedAt  appVersion
# 0                   False  False          True       True       False
# 1                   False  False          True       True       False
# 2                   False  False          True       True       False
# 3                   False  False          True       True       False
# 4                   False  False          True       True       False
# ..                    ...    ...           ...        ...         ...
# 995                 False  False          True       True       False
# 996                 False  False          True       True       False
# 997                 False  False          True       True       False
# 998                 False  False          True       True       False
# 999                 False  False          True       True       False
#
# [1000 rows x 11 columns]>

# %%
dd = data['score'].value_counts().reset_index()
dd.columns = ['score', 'Counts']
dd = dd.sort_values(by='score')
dd
# Out:
#    score  Counts
# 0      1     570
# 1      2     158
# 2      3     123
# 4      4      66
# 3      5      83

# %%
df = pd.DataFrame(data[['userName', 'content', 'score']])
df
# Out:
#                   userName                                            content  \
# 0        Damar Vikryansyah  Kurang ramah aplikasi instagram ini selalu ada...
# 1            Nazka Vayrena  kecewa karena musiknya jadi pada gada, ketika ...
# 2     farida haifatuzzahra  nggak jelas, makin di update malah jadi nggak ...
# 3           Yudha Adistira  Ada bug dimana akun utama saya tidak bisa repo...
# 4               Nuha 19 7K  Tolong bug nya diperbaiki ya, ini di akun ke d...
# ..                     ...                                                ...
# 995        susanto hariono  Aplikasi media sosial yang satu ini menghubung...
# 996        Abdul Qodir BSA  Dulu berjalan baik, semuanya normal, tpi setel...
# 997     Luvita Puspitasari  sedih banget karena fitur baru instagram repos...
# 998     Fiddiena Lestriena  Mohon segera diperbaiki. Berbagai fitur tambah...
# 999  Firgi Ardian Ramadhan  Kenapa setiap di tinggal terus di buka lagi ap...
#
#      score
# 0        3
# 1        1
# 2        1
# 3        1
# 4        3
# ..     ...
# 995      5
# 996      1
# 997      1
# 998      4
# 999      5
#
# [1000 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.barplot(x='score', y='Counts', data=dd)
plt.title('Histogram Score Aplikasi')
plt.xlabel('score')
plt.ylabel('Count')
plt.show()

# %%
data.to_csv('ScrapingInstagram.csv')
